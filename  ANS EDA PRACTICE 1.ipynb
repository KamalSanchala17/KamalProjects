# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings  as war

# %%
war.filterwarnings('ignore')

# %%
data = pd.read_csv('EDA_Practice_Dataset_1_.csv')
data
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
cd C:\Users\Kamal Sanchala\Desktop\finger tips cource\python\EDA PRACTICE
# Out:
# C:\Users\Kamal Sanchala\Desktop\finger tips cource\python\EDA PRACTICE

# %%
pd.set_option('display.max_rows',None)

# %%
data
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 5        A Dance with Dragons (A Song of Ice and Fire)
# 6    A Game of Thrones / A Clash of Kings / A Storm...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# 9                            A Man Called Ove: A Novel
# 10                           A Man Called Ove: A Novel
# 11   A Patriot's History of the United States: From...
# 12                             A Stolen Life: A Memoir
# 13                    A Wrinkle in Time (Time Quintet)
# 14   Act Like a Lady, Think Like a Man: What Men Re...
# 15   Adult Coloring Book Designs: Stress Relief Col...
# ...

# %%
data.dtypes # show data type
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %%
data.isnull().sum() # show null values
# Out:
# Name           0
# Author         0
# User Rating    0
# Reviews        0
# Price          0
# Year           0
# Genre          0
# dtype: int64

# %%
sns.countplot(x='User Rating',data=data); # show highest rating count

# %%
plt.figure(figsize=(15,20)) # show all column histogram
data.hist();

# %%
sns.relplot(x='Price',y='Reviews',hue='User Rating',style = 'Year', data=data)

# %%
data.shape # show columns and rows
# Out:
# (550, 7)

# %%
data.columns #show column name
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
data1 = data[data['Price'] != 0]
data1

mean = data1['Price'].mean()
mean
data.replace(0,mean) # show data replace to mean
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 5        A Dance with Dragons (A Song of Ice and Fire)
# 6    A Game of Thrones / A Clash of Kings / A Storm...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# 9                            A Man Called Ove: A Novel
# 10                           A Man Called Ove: A Novel
# 11   A Patriot's History of the United States: From...
# 12                             A Stolen Life: A Memoir
# 13                    A Wrinkle in Time (Time Quintet)
# 14   Act Like a Lady, Think Like a Man: What Men Re...
# 15   Adult Coloring Book Designs: Stress Relief Col...
# ...

# %%
data['User Rating'].max() #show maximum rating
# Out:
# 4.9

# %%
data.groupby(['Author']).max()['User Rating'] # show max rating list by Author
# Out:
# Author
# Abraham Verghese                      4.60
# Adam Gasiewski                        4.40
# Adam Mansbach                         4.80
# Adir Levy                             4.80
# Admiral William H. McRaven            4.70
# Adult Coloring Book Designs           4.50
# Alan Moore                            4.80
# Alex Michaelides                      4.50
# Alice Schertle                        4.90
# Allie Brosh                           4.70
# American Psychiatric Association      4.50
# American Psychological Association    4.50
# Amor Towles                           4.70
# Amy Ramos                             4.30
# Amy Shields                           4.80
# Andy Weir                             4.70
# Angie Grace                           4.60
# Angie Thomas                          4.80
# Ann Voskamp                           4.60
# Ann Whitford Paul                     4.80
# Anthony Bourdain                      4.80
# Anthony Doerr                         4.60
# ...

# %%
hight_rating = data[data['User Rating'] == 4.80]
hight_rating # high rating list
# Out:
#                                                   Name  \
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 19                                  Alexander Hamilton
# 30   Barefoot Contessa Foolproof: Recipes You Can T...
# 32                                            Becoming
# 33                                            Becoming
# 34   Being Mortal: Medicine and What Matters in the...
# 42          Cabin Fever (Diary of a Wimpy Kid, Book 6)
# 44   Can't Hurt Me: Master Your Mind and Defy the Odds
# 54   Creative Haven Creative Cats Coloring Book (Ad...
# 55   Creative Haven Owls Coloring Book (Adult Color...
# 58   Daring Greatly: How the Courage to Be Vulnerab...
# 63                      Dear Zoo: A Lift-the-Flap Book
# 64                      Dear Zoo: A Lift-the-Flap Book
# 65                      Dear Zoo: A Lift-the-Flap Book
# 66                      Dear Zoo: A Lift-the-Flap Book
# 71             Diary of a Wimpy Kid: Hard Luck, Book 8
# ...

# %%
hight_rating.count() # high rating count
# Out:
# Name           127
# Author         127
# User Rating    127
# Reviews        127
# Price          127
# Year           127
# Genre          127
# dtype: int64

# %%
sns.barplot(x='Author',y= 'User Rating',data=data)
# Out:
# <AxesSubplot:xlabel='Author', ylabel='User Rating'>

# %%
data.Author.value_counts().head(10).plot( kind='bar',color = 'y', figsize=(15,5)) # top 10 Auther
# Out:
# <AxesSubplot:>

# %%
data.Author.value_counts().nlargest(10).plot( kind='bar',color = 'y', figsize=(15,5)) # top 10 Author
# Out:
# <AxesSubplot:>

# %%
mean
# Out:
# 13.392193308550185

# %%
pd.set_eng_float_format(2,2) # set floting number

# %%
data.corr() # show co relation
# Out:
#              User Rating  Reviews    Price     Year
# User Rating         1.00   -1.73m -133.09m  242.38m
# Reviews           -1.73m     1.00 -109.18m  263.56m
# Price           -133.09m -109.18m     1.00 -153.98m
# Year             242.38m  263.56m -153.98m     1.00

# %%
plt.figure(figsize=(15,15))

sns.heatmap(data.corr(),annot=True,cmap = "crest") # show co relation
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='Genre',data=data); # show count of genre

# %%
sns.barplot(x='Year',y = 'Reviews',data=data); # year wisw Reviews count

# %%
data['Reviews'].max() # shoe max reviews
# Out:
# 87841

# %%
data2 = data[data['Reviews'] == 87841] # high rating Author name
data2
# Out:
#                         Name       Author  User Rating  Reviews  Price  Year  \
# 534  Where the Crawdads Sing  Delia Owens         4.80    87841     15  2019
#
#        Genre
# 534  Fiction

# %%
data.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')
